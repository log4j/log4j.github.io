# %% [markdown]
# <img src='https://jupyter.org/images/jupyter-sq-text.svg' width='320px'   />

# %%
# Python 3: Fibonacci series up to n
def fib(n):
    a, b = 0, 1
    while a < n:
        print(a, end=' ')
        a, b = b, a+b
    print()
fib(1000)
# Out:
#   File "<ipython-input-2-724a854fa970>", line 5
#     print(a, end=' ')
#                 ^
# SyntaxError: invalid syntax
